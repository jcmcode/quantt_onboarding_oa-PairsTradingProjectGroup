# %%
import time

for i in range(10, 0, -1):
    print(i)
    time.sleep(1)
    
print("Happy New Year!")

# %%
fruits = ["apple", "banana", "cherry"]

for fruit in fruits:
  print(fruit, end=" ")
# Out:
# apple banana cherry
